# %%
# https://itunes.apple.com/kr/rss/customerreviews/id=1141323821/sortBy=mostRecent/json
# https://itunes.apple.com/kr/rss/customerreviews/id=1141323821/sortBy=mostRecent/xml

# %%
import pandas as pd

import xmltodict
from urllib.request import urlopen
import json

# %%
res_dict = []
for j in range(1,4):
    url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=1141323821/sortby=mostrecent/xml?urlDesc=/customerreviews/id=597333937/sortBy=mostRecent/xml" % j
    response = urlopen(url).read()

    xml = xmltodict.parse(response)
    XmlToJson = json.loads(json.dumps(xml))

    for i in range(len(XmlToJson['feed']['entry'])):
        res_dict.append({
            'date' : XmlToJson['feed']['entry'][i]['updated'][:10],
            'ratings' : int(XmlToJson['feed']['entry'][i]['im:rating']),
            'helpful' : int(XmlToJson['feed']['entry'][i]['im:voteSum']),
            'comment' : XmlToJson['feed']['entry'][i]['content'][0]['#text']
        })

# %%
res_df = pd.DataFrame(res_dict)
res_df['date'] = pd.to_datetime(res_df['date'], format="%Y-%m-%d")

res_df.to_csv('마이머니_Appstore.csv', encoding='utf-8-sig', index=False)
res_df
# Out:
#           date  ratings  helpful  \
# 0   2020-11-16        1        0
# 1   2020-11-09        1        0
# 2   2020-11-06        1        0
# 3   2020-11-02        4        0
# 4   2020-10-29        1        0
# ..         ...      ...      ...
# 145 2017-01-23        1        0
# 146 2017-01-22        5        0
# 147 2017-01-16        3        0
# 148 2017-01-16        5        0
# 149 2017-01-15        4        0
#
#                                                comment
# 0                                          이걸 어뜨케 쓰지..
# 1    이 앱 국민은행이 만든거 맞아요?? 공인인증서로 연동했는데 다른 금융사 정보 하나도...
# 2       화면에 있는 승인번호를 아무리 눌러도 잘못된 번호라 계속 오류나네요 수정좀 해주세요
# 3                           해외주식도 같이 볼수있게 해주세요\nPlease
# 4    국민은행 앱들 다 좋은데 그걸 하나로 합치면 안 될까요 정말 불편합니다 ... 스타...
# ..                                                 ...
# 145  제 공인인증서 암호 글자수가 20글자 이상인데\n국민은행 외에 다른은행을 추가시 \...
# 146                              그런데 우체국보험 추기할수있게해주세요?
# 147  이용하는 증권사가 두개있는데 둘 가 없네요 빠른 추가 부탁드립니다\n키움 kb증권 ...
# ...

# %%
train = pd.read_csv('마이머니_Appstore.csv')
train
# Out:
#            date  ratings  helpful  \
# 0    2020-11-16        1        0
# 1    2020-11-09        1        0
# 2    2020-11-06        1        0
# 3    2020-11-02        4        0
# 4    2020-10-29        1        0
# ..          ...      ...      ...
# 145  2017-01-23        1        0
# 146  2017-01-22        5        0
# 147  2017-01-16        3        0
# 148  2017-01-16        5        0
# 149  2017-01-15        4        0
#
#                                                comment
# 0                                          이걸 어뜨케 쓰지..
# 1    이 앱 국민은행이 만든거 맞아요?? 공인인증서로 연동했는데 다른 금융사 정보 하나도...
# 2       화면에 있는 승인번호를 아무리 눌러도 잘못된 번호라 계속 오류나네요 수정좀 해주세요
# 3                           해외주식도 같이 볼수있게 해주세요\nPlease
# 4    국민은행 앱들 다 좋은데 그걸 하나로 합치면 안 될까요 정말 불편합니다 ... 스타...
# ..                                                 ...
# 145  제 공인인증서 암호 글자수가 20글자 이상인데\n국민은행 외에 다른은행을 추가시 \...
# 146                              그런데 우체국보험 추기할수있게해주세요?
# ...
